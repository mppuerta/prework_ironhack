# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
#Rock, paper, scissors


variables = ['rock', 'paper', 'scissors']


import random

computerchoice = []
humanchoice = []
battle = []


def computer():
    "Function that randomly returns a value"
    comp = random.choice(variables)
    computerchoice.append(comp)



def human():
    "Function that asks player for his choice"
    while True:
        hum = input("Human's choice: ")
        if hum in variables:
            humanchoice.append(hum)
            break
        else:
            print("I'm sorry, you can't battle with that... Try again!")

            
def battles():
    "Function that resolves the combact"
    if humanchoice[0] == 'scissors':
        if computerchoice[0] == 'paper':
            battle.append (2)
        elif computerchoice[0] == 'rock':
            battle.append (1)
        elif computerchoice[0] == 'scissors':
            battle.append (0)
            
    elif humanchoice[0] == 'paper':
        if computerchoice[0] == 'rock':
            battle.append (2)
        elif computerchoice[0] == 'scissors':
            battle.append (1)
        elif computerchoice[0] == 'paper':
            battle.append (0)
            
    elif humanchoice[0] == 'rock':
        if computerchoice[0] == 'scissors':
            battle.append (2)
        elif computerchoice[0] == 'paper':
            battle.append (1)
        elif computerchoice[0] == 'rock':
            battle.append (0)
                 

Human_won = [0]
Machine_won = [0]         
            
            
def scoreboard():
    "Function that shows each player's choice and the state of the game"
    print("Machine's choice:", computerchoice[0])
    if battle[0] == 2:
        Human_won[0] += 1
    elif battle[0] == 1:
        Machine_won[0] += 1
    elif battle[0] == 0:
        print('TIE')
    print("Human won:", Human_won[0])
    print("Machine won:", Machine_won[0])
    

winner = 0
roundswon = 5

while winner < roundswon:
    computerchoice = []
    humanchoice = []
    battle = []
    computer()
    human()
    battles()
    scoreboard()
    winner = max([Human_won[0],Machine_won[0]])
    print("")


results = {'Human': Human_won[0], 'Machine': Machine_won[0]}

for key,value in results.items():
    if value == roundswon:
        print ('Winner: ', key)
# Out:
# Human's choice: rock
# Machine's choice: paper
# Human won: 0
# Machine won: 1
#
# Human's choice: paper
# Machine's choice: rock
# Human won: 1
# Machine won: 1
#
# Human's choice: rock
# Machine's choice: paper
# Human won: 1
# Machine won: 2
#
# Human's choice: paper
# Machine's choice: scissors
# Human won: 1
# Machine won: 3
#
# Human's choice: scissors
# Machine's choice: paper
# Human won: 2
# Machine won: 3
#
# Human's choice: k
# I'm sorry, you can't battle with that... Try again!
# Human's choice: rock
# Machine's choice: scissors
# Human won: 3
# Machine won: 3
#
# Human's choice: rock
# Machine's choice: scissors
# Human won: 4
# Machine won: 3
#
# Human's choice: rock
# Machine's choice: rock
# TIE
# Human won: 4
# Machine won: 3
#
# Human's choice: rock
# Machine's choice: rock
# TIE
# Human won: 4
# Machine won: 3
#
# Human's choice: rock
# Machine's choice: scissors
# Human won: 5
# Machine won: 3
#
# Winner:  Human

# %% [raw]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# #Rock, paper, scissorsTip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
variables = ['rock', 'paper', 'scissors','lizard','spock']

maxgames = 0
wins = 0

def games():
    "Function that sets the maximum number of rounds"
    while True:
        global maxgames
        global wins
        try:
            maxgames = int(input("Select the maximum number of rounds: "))
            print('')
            oddnumber = maxgames/2
            wins = int(float(oddnumber)) + 1
        except:
            print("That's not even a number!")
            continue
        try:
            if oddnumber == int(float(oddnumber)):
                raise ValueError
            else:
                return maxgames
        except:
            print("That's not an odd number :)")
    
    
comp = 0
hum = 0
battle = 0  
    
import random 
    
def computer():
    "Function that randomly returns a value"
    global comp
    comp = random.choice(variables)


def human():
    "Function that asks player for his choice"
    while True:
        global hum
        hum = input("Human's choice: ")
        if hum in variables:
            return hum
        else:
            print("I'm sorry, you can't battle with that... Try again!")

            
def battles(comp,hum):
    "Function that resolves the combact"
    global battle
    if hum == 'rock':
        if comp == 'rock':
            battle = 0
        elif comp == 'paper':
            battle = 1
        elif comp == 'scissors':
            battle = 2
        elif comp == 'lizard':
            battle = 2
        elif comp == 'spock':
            battle = 1
            
    elif hum == 'paper':
        if comp == 'rock':
            battle = 2
        elif comp == 'paper':
            battle = 0
        elif comp == 'scissors':
            battle = 1
        elif comp == 'lizard':
            battle = 1
        elif comp == 'spock':
            battle = 2
            
    elif hum == 'scissors':
        if comp == 'rock':
            battle = 1
        elif comp == 'paper':
            battle = 2
        elif comp == 'scissors':
            battle = 0
        elif comp == 'lizard':
            battle = 2
        elif comp == 'spock':
            battle = 1
      
    elif hum == 'lizard':
        if comp == 'rock':
            battle = 1
        elif comp == 'paper':
            battle = 2
        elif comp == 'scissors':
            battle = 1
        elif comp == 'lizard':
            battle = 0
        elif comp == 'spock':
            battle = 2
            
    elif hum == 'spock':
        if comp == 'rock':
            battle = 2
        elif comp == 'paper':
            battle = 1
        elif comp == 'scissors':
            battle = 2
        elif comp == 'lizard':
            battle = 1
        elif comp == 'spock':
            battle = 0

            
Human_won = 0
Machine_won = 0
            
            
def scoreboard():
    "Function that shows each player's choice and the state of the game"
    print("Machine's choice:", comp)
    global Human_won
    global Machine_won
    if battle == 2:
        Human_won += 1
    elif battle == 1:
        Machine_won += 1
    elif battle == 0:
        print('TIE')
    print("Human won:", Human_won)
    print("Machine won:", Machine_won)


games()


maxwins = 0

for i in range(maxgames):
    computer()
    human()
    battles(comp,hum)
    scoreboard()
    maxwins = max([Human_won,Machine_won])
    results = {'Human': Human_won, 'Machine': Machine_won}
    if maxwins == wins:
        for key,value in results.items():
            if value == wins:
                print('')
                print ('Winner: ', key)
                break
    elif i == (maxgames - 1):
        if Human_won == Machine_won:
            print('')
            print('There was a tie')
            break
        elif Human_won != Machine_won:
            winner = max(results.values())
            for key,value in results.items():
                if value == winner:
                    print('')
                    print ('Winner: ', key)
                    break
        
    print("")
# Out:
# Select the maximum number of rounds: rock
# That's not even a number!
# Select the maximum number of rounds: rock
# That's not even a number!
# Select the maximum number of rounds: 5
#
# Human's choice: rock
# Machine's choice: scissors
# Human won: 1
# Machine won: 0
#
# Human's choice: rock
# Machine's choice: paper
# Human won: 1
# Machine won: 1
#
# Human's choice: rock
# Machine's choice: spock
# Human won: 1
# Machine won: 2
#
# Human's choice: rock
# Machine's choice: lizard
# Human won: 2
# Machine won: 2
#
# Human's choice: rock
# Machine's choice: spock
# Human won: 2
# Machine won: 3
#
# Winner:  Machine

# %% [raw]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
